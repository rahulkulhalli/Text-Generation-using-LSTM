# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset , DataLoader
import re
import random

# %%
# load & read file
dataset_name = "shakespeare.txt"
raw_data = open(dataset_name, "r").read().lower()

# %%
raw_data
# Out:
# 'now,fair hippolyta,our nuptial hour draws on apace : four happy days bring in another moon;but o ! methinks how slow this old moon wanes;she lingers my desires,like to a step dame,or a dowager long withering out a young man\'s revenue.four days will quickly steep themselves in night;four nights will quickly dream away the time;and then the moon,like to a silver bow new-bent in heaven,shall behold the night of our solemnities. go,philostrate,stir up the athenian youth to merriments;awake the pert and nimble spirit of mirth;turn melancholy forth to funerals;the pale companion is not for our pomp.hippolyta,i woo\'d thee with my sword,and won thy love doing thee injuries;but i will wed thee in another key,with pomp,with triumph,and with revelling.happy be theseus,our renowned duke !thanks,good egeus : what\'s the news with thee ?full of vexation come i,with complaint against my child,my daughter hermia.stand forth,demetrius.my noble lord,this man hath my consent to marry her.stand forth,lysander : and,my gracious duke,this man hath bewitch\'d the bosom of my child :thou,thou,lysander,thou hast given her rimes,and interchang\'d love-tokens with my child;thou hast by moonlight at her window sung,with feigning voice,verses of feigning love;and stol\'n the impression of her fantasy with bracelets of thy hair,rings,gawds,conceits,knacks,trifles,nosegays,sweetmeats,messengers of strong prevailment in unharden\'d youth;with cunning hast thou filch\'d my daughter\'s heart;turn\'d her obedience,which is due to me,to stubborn harshness.and,my gracious duke,be it so she will not here before your grace consent to marry with demetrius,i beg the ancient privilege of athens,as she is mine,i may dispose of her;which shall be either to this gentleman,or to her death,according to our law immediately provided in that case.what say you,hermia ? be advis\'d,fair maid.to you,your father should be as a god;one that compos\'d your beauties,yea,and one to whom you are but as a form in wax by him imprinted,and within his power to leave the figure or disfigure it.demetrius is a worthy gentleman.so is lysander.in himself he is;but,in this kind,wanting your father\'s voice,the other must be held the worthier.i would my father look\'d but with my eyes.rather your eyes must with his judgment look.i do entreat your grace to pardon me.i know not by what power i am made bold,nor how it may concern my modesty in such a presence here to plead my thoughts;but i beseech your grace,that i may know the worst that may befall me in this case,if i refuse to wed demetrius.either to die the death,or to abjure for ever the society of men.therefore,fair hermia,question your desires;know of your youth,examine well your blood,whe\'r,if you yield not to your father\'s choice,you can endure the livery of a nun,for aye to be in shady cloister mew\'d,to live a barren sister all your life,chanting faint hymns to the cold fruitless moon.thrice blessed they that master so their blood,to undergo such maiden pilgrimage;but earthlier happy is the rose distill\'d,than that which withering on the virgin thorn grows,lives,and dies,in single blessedness.so will i grow,so live,so die,my lord,ere i will yield my virgin patent up unto his lordship,whose unwished yoke my soul consents not to give sovereignty.take time to pause;and,by the next new moon,the sealing-day betwixt my love and me for everlasting bond of fellowship,upon that day either prepare to die for disobedience to your father\'s will,or else to wed demetrius,as he would;or on diana\'s altar to protest for aye austerity and single life.relent,sweet hermia;and,lysander,yield thy crazed title to my certain right.you have her father\'s love,demetrius;let me have hermia\'s : do you marry him.scornful lysander ! true,he hath my love,and what is mine my love shall render him;and she is mine,and all my right of her i do estate unto demetrius.i am,my lord,as well deriv\'d as he,as well possess\'d;my love is more than his;my fortunes every  ...

# %%
len(raw_data)
# Out:
# 302259

# %%
#clean data
clean_data = re.sub(r'[^\w\s]', " ", raw_data)

# %%
clean_data
# Out:
# 'now fair hippolyta our nuptial hour draws on apace   four happy days bring in another moon but o   methinks how slow this old moon wanes she lingers my desires like to a step dame or a dowager long withering out a young man s revenue four days will quickly steep themselves in night four nights will quickly dream away the time and then the moon like to a silver bow new bent in heaven shall behold the night of our solemnities  go philostrate stir up the athenian youth to merriments awake the pert and nimble spirit of mirth turn melancholy forth to funerals the pale companion is not for our pomp hippolyta i woo d thee with my sword and won thy love doing thee injuries but i will wed thee in another key with pomp with triumph and with revelling happy be theseus our renowned duke  thanks good egeus   what s the news with thee  full of vexation come i with complaint against my child my daughter hermia stand forth demetrius my noble lord this man hath my consent to marry her stand forth lysander   and my gracious duke this man hath bewitch d the bosom of my child  thou thou lysander thou hast given her rimes and interchang d love tokens with my child thou hast by moonlight at her window sung with feigning voice verses of feigning love and stol n the impression of her fantasy with bracelets of thy hair rings gawds conceits knacks trifles nosegays sweetmeats messengers of strong prevailment in unharden d youth with cunning hast thou filch d my daughter s heart turn d her obedience which is due to me to stubborn harshness and my gracious duke be it so she will not here before your grace consent to marry with demetrius i beg the ancient privilege of athens as she is mine i may dispose of her which shall be either to this gentleman or to her death according to our law immediately provided in that case what say you hermia   be advis d fair maid to you your father should be as a god one that compos d your beauties yea and one to whom you are but as a form in wax by him imprinted and within his power to leave the figure or disfigure it demetrius is a worthy gentleman so is lysander in himself he is but in this kind wanting your father s voice the other must be held the worthier i would my father look d but with my eyes rather your eyes must with his judgment look i do entreat your grace to pardon me i know not by what power i am made bold nor how it may concern my modesty in such a presence here to plead my thoughts but i beseech your grace that i may know the worst that may befall me in this case if i refuse to wed demetrius either to die the death or to abjure for ever the society of men therefore fair hermia question your desires know of your youth examine well your blood whe r if you yield not to your father s choice you can endure the livery of a nun for aye to be in shady cloister mew d to live a barren sister all your life chanting faint hymns to the cold fruitless moon thrice blessed they that master so their blood to undergo such maiden pilgrimage but earthlier happy is the rose distill d than that which withering on the virgin thorn grows lives and dies in single blessedness so will i grow so live so die my lord ere i will yield my virgin patent up unto his lordship whose unwished yoke my soul consents not to give sovereignty take time to pause and by the next new moon the sealing day betwixt my love and me for everlasting bond of fellowship upon that day either prepare to die for disobedience to your father s will or else to wed demetrius as he would or on diana s altar to protest for aye austerity and single life relent sweet hermia and lysander yield thy crazed title to my certain right you have her father s love demetrius let me have hermia s   do you marry him scornful lysander   true he hath my love and what is mine my love shall render him and she is mine and all my right of her i do estate unto demetrius i am my lord as well deriv d as he as well possess d my love is more than his my fortunes every way as fairly rank d if  ...

# %%
len(clean_data)
# Out:
# 302259

# %% [markdown]
# # Creating Sequence

# %%
def create_seq(text,seq_len=8):
  
  
  sequence = []
  
  if len(text.split()) > seq_len:
    for i in range(seq_len,len(text.split())):
      #select the sequnece of tokens
      seq = text.split()[i-seq_len:i+1] 
      sequence.append(" ".join(seq))

    return sequence


  else:
    return [text]

# %%
raw_seq= create_seq(clean_data)

# %%
raw_seq
# Out:
# ['now fair hippolyta our nuptial hour draws on apace',
#  'fair hippolyta our nuptial hour draws on apace four',
#  'hippolyta our nuptial hour draws on apace four happy',
#  'our nuptial hour draws on apace four happy days',
#  'nuptial hour draws on apace four happy days bring',
#  'hour draws on apace four happy days bring in',
#  'draws on apace four happy days bring in another',
#  'on apace four happy days bring in another moon',
#  'apace four happy days bring in another moon but',
#  'four happy days bring in another moon but o',
#  'happy days bring in another moon but o methinks',
#  'days bring in another moon but o methinks how',
#  'bring in another moon but o methinks how slow',
#  'in another moon but o methinks how slow this',
#  'another moon but o methinks how slow this old',
#  'moon but o methinks how slow this old moon',
#  'but o methinks how slow this old moon wanes',
#  'o methinks how slow this old moon wanes she',
#  'methinks how slow this old moon wanes she lingers',
#  'how slow this old moon wanes she lingers my',
#  'slow this old moon wanes she lingers my desires',
#  'this old moon wanes she lingers my desires like',
#  'old moon wanes she lingers my desires like to',
#  'moon wanes she lingers my desires like to a',
#  'wanes she lingers my desires like to a step',
#  'she lingers my desires like to a step dame',
#  'lingers my desires like to a step dame or',
#  'my desires like to a step dame or a',
#  'desires like to a step dame or a dowager',
#  'like to a step dame or a dowager long',
#  'to a step dame or a dowager long withering',
#  'a step dame or a dowager long withering out',
#  'step dame or a dowager long withering out a',
#  'dame or a dowager long withering out a young',
#  'or a dowager long withering out a young man',
#  'a dowager long withering out a young man s',
#  'dowager long withering out a young man s revenue',
#  'long withering out a young man s revenue four',
#  'withering out a young man s revenue four days',
#  'out a young man s revenue four days will',
#  'a young man s revenue four days will quickly',
#  'young man s revenue four days will quickly steep',
#  'man s revenue four days will quickly steep themselves',
#  's revenue four days will quickly steep themselves in',
#  'revenue four days will quickly steep themselves in night',
#  'four days will quickly steep themselves in night four',
#  'days will quickly steep themselves in night four nights',
#  'will quickly steep themselves in night four nights will',
#  'quickly steep themselves in night four nights will quickly',
#  'steep themselves in night four nights will quickly dream',
#  'themselves in night four nights will quickly dream away',
#  'in night four nights will quickly dream away the',
#  'night four nights will quickly dream away the time',
#  'four nights will quickly dream away the time and',
#  'nights will quickly dream away the time and then',
#  'will quickly dream away the time and then the',
#  'quickly dream away the time and then the moon',
#  'dream away the time and then the moon like',
#  'away the time and then the moon like to',
#  'the time and then the moon like to a',
#  'time and then the moon like to a silver',
#  'and then the moon like to a silver bow',
#  'then the moon like to a silver bow new',
#  'the moon like to a silver bow new bent',
#  'moon like to a silver bow new bent in',
#  'like to a silver bow new bent in heaven',
#  'to a silver bow new bent in heaven shall',
#  'a silver bow new bent in heaven shall behold',
#  'silver bow new bent in heaven shall behold the',
#  'bow new bent in heaven shall behold the night',
#  'new bent in heaven shall behold the night of',
#  'bent in heaven shall behold the night of our',
#  'in heaven shall behold the night of our solemnities',
#  'heaven shall behold the night of our solemnities go',
#  'shall behold the night of our solemnities go philostrate',
#  'behold the night of our solemnities go philostrate stir',
#  'the night of our solemnities go philostrate stir up',
#  'night of our solemnities go philostrate stir up the',
#  'of our solemnities go philostrate stir up the athenian',
#  'our solemnities go philostrate stir up the athenian youth',
#  'solemnities go philostrate stir up the athenian youth to',
#  'go philostrate stir up the athenian youth to merriments',
#  'philostrate stir up the athenian youth to merriments awake',
#  'stir up the athenian youth to merriments awake the',
#  'up the athenian youth to merriments awake the pert',
#  'the athenian youth to merriments awake the pert and',
#  'athenian youth to merriments awake the pert and nimble',
#  'youth to merriments awake the pert and nimble spirit',
#  'to merriments awake the pert and nimble spirit of',
#  'merriments awake the pert and nimble spirit of mirth',
#  'awake the pert and nimble spirit of mirth turn',
#  'the pert and nimble spirit of mirth turn melancholy',
#  'pert and nimble spirit of mirth turn melancholy forth',
#  'and nimble spirit of mirth turn melancholy forth to',
#  'nimble spirit of mirth turn melancholy forth to funerals',
#  'spirit of mirth turn melancholy forth to funerals the',
#  'of mirth turn melancholy forth to funerals the pale',
#  'mirth turn melancholy forth to funerals the pale companion',
#  'turn melancholy forth to funerals the pale companion is',
#  'melancholy forth to funerals the pale companion is not',
#  'forth to funerals the pale companion is not for',
#  'to funerals the pale companion is not for our',
#  'funerals the pale companion is not for our pomp',
#  'the pale companion is not for our pomp hippolyta',
#  'pale companion is not for our pomp hippolyta i',
#  'companion is not for our pomp hippolyta i woo',
#  'is not for our pomp hippolyta i woo d',
#  'not for our pomp hippolyta i woo d thee',
#  'for our pomp hippolyta i woo d thee with',
#  'our pomp hippolyta i woo d thee with my',
#  'pomp hippolyta i woo d thee with my sword',
#  'hippolyta i woo d thee with my sword and',
#  'i woo d thee with my sword and won',
#  'woo d thee with my sword and won thy',
#  'd thee with my sword and won thy love',
#  'thee with my sword and won thy love doing',
#  'with my sword and won thy love doing thee',
#  'my sword and won thy love doing thee injuries',
#  'sword and won thy love doing thee injuries but',
#  'and won thy love doing thee injuries but i',
#  'won thy love doing thee injuries but i will',
#  'thy love doing thee injuries but i will wed',
#  'love doing thee injuries but i will wed thee',
#  'doing thee injuries but i will wed thee in',
#  'thee injuries but i will wed thee in another',
#  'injuries but i will wed thee in another key',
#  'but i will wed thee in another key with',
#  'i will wed thee in another key with pomp',
#  'will wed thee in another key with pomp with',
#  'wed thee in another key with pomp with triumph',
#  'thee in another key with pomp with triumph and',
#  'in another key with pomp with triumph and with',
#  'another key with pomp with triumph and with revelling',
#  'key with pomp with triumph and with revelling happy',
#  'with pomp with triumph and with revelling happy be',
#  'pomp with triumph and with revelling happy be theseus',
#  'with triumph and with revelling happy be theseus our',
#  'triumph and with revelling happy be theseus our renowned',
#  'and with revelling happy be theseus our renowned duke',
#  'with revelling happy be theseus our renowned duke thanks',
#  'revelling happy be theseus our renowned duke thanks good',
#  'happy be theseus our renowned duke thanks good egeus',
#  'be theseus our renowned duke thanks good egeus what',
#  'theseus our renowned duke thanks good egeus what s',
#  'our renowned duke thanks good egeus what s the',
#  'renowned duke thanks good egeus what s the news',
#  'duke thanks good egeus what s the news with',
#  'thanks good egeus what s the news with thee',
#  'good egeus what s the news with thee full',
#  'egeus what s the news with thee full of',
#  'what s the news with thee full of vexation',
#  's the news with thee full of vexation come',
#  'the news with thee full of vexation come i',
#  'news with thee full of vexation come i with',
#  'with thee full of vexation come i with complaint',
#  'thee full of vexation come i with complaint against',
#  'full of vexation come i with complaint against my',
#  'of vexation come i with complaint against my child',
#  'vexation come i with complaint against my child my',
#  'come i with complaint against my child my daughter',
#  'i with complaint against my child my daughter hermia',
#  'with complaint against my child my daughter hermia stand',
#  'complaint against my child my daughter hermia stand forth',
#  'against my child my daughter hermia stand forth demetrius',
#  'my child my daughter hermia stand forth demetrius my',
#  'child my daughter hermia stand forth demetrius my noble',
#  'my daughter hermia stand forth demetrius my noble lord',
#  'daughter hermia stand forth demetrius my noble lord this',
#  'hermia stand forth demetrius my noble lord this man',
#  'stand forth demetrius my noble lord this man hath',
#  'forth demetrius my noble lord this man hath my',
#  'demetrius my noble lord this man hath my consent',
#  'my noble lord this man hath my consent to',
#  'noble lord this man hath my consent to marry',
#  'lord this man hath my consent to marry her',
#  'this man hath my consent to marry her stand',
#  'man hath my consent to marry her stand forth',
#  'hath my consent to marry her stand forth lysander',
#  'my consent to marry her stand forth lysander and',
#  'consent to marry her stand forth lysander and my',
#  'to marry her stand forth lysander and my gracious',
#  'marry her stand forth lysander and my gracious duke',
#  'her stand forth lysander and my gracious duke this',
#  'stand forth lysander and my gracious duke this man',
#  'forth lysander and my gracious duke this man hath',
#  'lysander and my gracious duke this man hath bewitch',
#  'and my gracious duke this man hath bewitch d',
#  'my gracious duke this man hath bewitch d the',
#  'gracious duke this man hath bewitch d the bosom',
#  'duke this man hath bewitch d the bosom of',
#  'this man hath bewitch d the bosom of my',
#  'man hath bewitch d the bosom of my child',
#  'hath bewitch d the bosom of my child thou',
#  'bewitch d the bosom of my child thou thou',
#  'd the bosom of my child thou thou lysander',
#  'the bosom of my child thou thou lysander thou',
#  'bosom of my child thou thou lysander thou hast',
#  'of my child thou thou lysander thou hast given',
#  'my child thou thou lysander thou hast given her',
#  'child thou thou lysander thou hast given her rimes',
#  'thou thou lysander thou hast given her rimes and',
#  'thou lysander thou hast given her rimes and interchang',
#  'lysander thou hast given her rimes and interchang d',
#  'thou hast given her rimes and interchang d love',
#  'hast given her rimes and interchang d love tokens',
#  'given her rimes and interchang d love tokens with',
#  'her rimes and interchang d love tokens with my',
#  'rimes and interchang d love tokens with my child',
#  'and interchang d love tokens with my child thou',
#  'interchang d love tokens with my child thou hast',
#  'd love tokens with my child thou hast by',
#  'love tokens with my child thou hast by moonlight',
#  'tokens with my child thou hast by moonlight at',
#  'with my child thou hast by moonlight at her',
#  'my child thou hast by moonlight at her window',
#  'child thou hast by moonlight at her window sung',
#  'thou hast by moonlight at her window sung with',
#  'hast by moonlight at her window sung with feigning',
#  'by moonlight at her window sung with feigning voice',
#  'moonlight at her window sung with feigning voice verses',
#  'at her window sung with feigning voice verses of',
#  'her window sung with feigning voice verses of feigning',
#  'window sung with feigning voice verses of feigning love',
#  'sung with feigning voice verses of feigning love and',
#  'with feigning voice verses of feigning love and stol',
#  'feigning voice verses of feigning love and stol n',
#  'voice verses of feigning love and stol n the',
#  'verses of feigning love and stol n the impression',
#  'of feigning love and stol n the impression of',
#  'feigning love and stol n the impression of her',
#  'love and stol n the impression of her fantasy',
#  'and stol n the impression of her fantasy with',
#  'stol n the impression of her fantasy with bracelets',
#  'n the impression of her fantasy with bracelets of',
#  'the impression of her fantasy with bracelets of thy',
#  'impression of her fantasy with bracelets of thy hair',
#  'of her fantasy with bracelets of thy hair rings',
#  'her fantasy with bracelets of thy hair rings gawds',
#  'fantasy with bracelets of thy hair rings gawds conceits',
#  'with bracelets of thy hair rings gawds conceits knacks',
#  'bracelets of thy hair rings gawds conceits knacks trifles',
#  'of thy hair rings gawds conceits knacks trifles nosegays',
#  'thy hair rings gawds conceits knacks trifles nosegays sweetmeats',
#  'hair rings gawds conceits knacks trifles nosegays sweetmeats messengers',
#  'rings gawds conceits knacks trifles nosegays sweetmeats messengers of',
#  'gawds conceits knacks trifles nosegays sweetmeats messengers of strong',
#  'conceits knacks trifles nosegays sweetmeats messengers of strong prevailment',
#  'knacks trifles nosegays sweetmeats messengers of strong prevailment in',
#  'trifles nosegays sweetmeats messengers of strong prevailment in unharden',
#  'nosegays sweetmeats messengers of strong prevailment in unharden d',
#  'sweetmeats messengers of strong prevailment in unharden d youth',
#  'messengers of strong prevailment in unharden d youth with',
#  'of strong prevailment in unharden d youth with cunning',
#  'strong prevailment in unharden d youth with cunning hast',
#  'prevailment in unharden d youth with cunning hast thou',
#  'in unharden d youth with cunning hast thou filch',
#  'unharden d youth with cunning hast thou filch d',
#  'd youth with cunning hast thou filch d my',
#  'youth with cunning hast thou filch d my daughter',
#  'with cunning hast thou filch d my daughter s',
#  'cunning hast thou filch d my daughter s heart',
#  'hast thou filch d my daughter s heart turn',
#  'thou filch d my daughter s heart turn d',
#  'filch d my daughter s heart turn d her',
#  'd my daughter s heart turn d her obedience',
#  'my daughter s heart turn d her obedience which',
#  'daughter s heart turn d her obedience which is',
#  's heart turn d her obedience which is due',
#  'heart turn d her obedience which is due to',
#  'turn d her obedience which is due to me',
#  'd her obedience which is due to me to',
#  'her obedience which is due to me to stubborn',
#  'obedience which is due to me to stubborn harshness',
#  'which is due to me to stubborn harshness and',
#  'is due to me to stubborn harshness and my',
#  'due to me to stubborn harshness and my gracious',
#  'to me to stubborn harshness and my gracious duke',
#  'me to stubborn harshness and my gracious duke be',
#  'to stubborn harshness and my gracious duke be it',
#  'stubborn harshness and my gracious duke be it so',
#  'harshness and my gracious duke be it so she',
#  'and my gracious duke be it so she will',
#  'my gracious duke be it so she will not',
#  'gracious duke be it so she will not here',
#  'duke be it so she will not here before',
#  'be it so she will not here before your',
#  'it so she will not here before your grace',
#  'so she will not here before your grace consent',
#  'she will not here before your grace consent to',
#  'will not here before your grace consent to marry',
#  'not here before your grace consent to marry with',
#  'here before your grace consent to marry with demetrius',
#  'before your grace consent to marry with demetrius i',
#  'your grace consent to marry with demetrius i beg',
#  'grace consent to marry with demetrius i beg the',
#  'consent to marry with demetrius i beg the ancient',
#  'to marry with demetrius i beg the ancient privilege',
#  'marry with demetrius i beg the ancient privilege of',
#  'with demetrius i beg the ancient privilege of athens',
#  'demetrius i beg the ancient privilege of athens as',
#  'i beg the ancient privilege of athens as she',
#  'beg the ancient privilege of athens as she is',
#  'the ancient privilege of athens as she is mine',
#  'ancient privilege of athens as she is mine i',
#  'privilege of athens as she is mine i may',
#  'of athens as she is mine i may dispose',
#  'athens as she is mine i may dispose of',
#  'as she is mine i may dispose of her',
#  'she is mine i may dispose of her which',
#  'is mine i may dispose of her which shall',
#  'mine i may dispose of her which shall be',
#  'i may dispose of her which shall be either',
#  'may dispose of her which shall be either to',
#  'dispose of her which shall be either to this',
#  'of her which shall be either to this gentleman',
#  'her which shall be either to this gentleman or',
#  'which shall be either to this gentleman or to',
#  'shall be either to this gentleman or to her',
#  'be either to this gentleman or to her death',
#  'either to this gentleman or to her death according',
#  'to this gentleman or to her death according to',
#  'this gentleman or to her death according to our',
#  'gentleman or to her death according to our law',
#  'or to her death according to our law immediately',
#  'to her death according to our law immediately provided',
#  'her death according to our law immediately provided in',
#  'death according to our law immediately provided in that',
#  'according to our law immediately provided in that case',
#  'to our law immediately provided in that case what',
#  'our law immediately provided in that case what say',
#  'law immediately provided in that case what say you',
#  'immediately provided in that case what say you hermia',
#  'provided in that case what say you hermia be',
#  'in that case what say you hermia be advis',
#  'that case what say you hermia be advis d',
#  'case what say you hermia be advis d fair',
#  'what say you hermia be advis d fair maid',
#  'say you hermia be advis d fair maid to',
#  'you hermia be advis d fair maid to you',
#  'hermia be advis d fair maid to you your',
#  'be advis d fair maid to you your father',
#  'advis d fair maid to you your father should',
#  'd fair maid to you your father should be',
#  'fair maid to you your father should be as',
#  'maid to you your father should be as a',
#  'to you your father should be as a god',
#  'you your father should be as a god one',
#  'your father should be as a god one that',
#  'father should be as a god one that compos',
#  'should be as a god one that compos d',
#  'be as a god one that compos d your',
#  'as a god one that compos d your beauties',
#  'a god one that compos d your beauties yea',
#  'god one that compos d your beauties yea and',
#  'one that compos d your beauties yea and one',
#  'that compos d your beauties yea and one to',
#  'compos d your beauties yea and one to whom',
#  'd your beauties yea and one to whom you',
#  'your beauties yea and one to whom you are',
#  'beauties yea and one to whom you are but',
#  'yea and one to whom you are but as',
#  'and one to whom you are but as a',
#  'one to whom you are but as a form',
#  'to whom you are but as a form in',
#  'whom you are but as a form in wax',
#  'you are but as a form in wax by',
#  'are but as a form in wax by him',
#  'but as a form in wax by him imprinted',
#  'as a form in wax by him imprinted and',
#  'a form in wax by him imprinted and within',
#  'form in wax by him imprinted and within his',
#  'in wax by him imprinted and within his power',
#  'wax by him imprinted and within his power to',
#  'by him imprinted and within his power to leave',
#  'him imprinted and within his power to leave the',
#  'imprinted and within his power to leave the figure',
#  'and within his power to leave the figure or',
#  'within his power to leave the figure or disfigure',
#  'his power to leave the figure or disfigure it',
#  'power to leave the figure or disfigure it demetrius',
#  'to leave the figure or disfigure it demetrius is',
#  'leave the figure or disfigure it demetrius is a',
#  'the figure or disfigure it demetrius is a worthy',
#  'figure or disfigure it demetrius is a worthy gentleman',
#  'or disfigure it demetrius is a worthy gentleman so',
#  'disfigure it demetrius is a worthy gentleman so is',
#  'it demetrius is a worthy gentleman so is lysander',
#  'demetrius is a worthy gentleman so is lysander in',
#  'is a worthy gentleman so is lysander in himself',
#  'a worthy gentleman so is lysander in himself he',
#  'worthy gentleman so is lysander in himself he is',
#  'gentleman so is lysander in himself he is but',
#  'so is lysander in himself he is but in',
#  'is lysander in himself he is but in this',
#  'lysander in himself he is but in this kind',
#  'in himself he is but in this kind wanting',
#  'himself he is but in this kind wanting your',
#  'he is but in this kind wanting your father',
#  'is but in this kind wanting your father s',
#  'but in this kind wanting your father s voice',
#  'in this kind wanting your father s voice the',
#  'this kind wanting your father s voice the other',
#  'kind wanting your father s voice the other must',
#  'wanting your father s voice the other must be',
#  'your father s voice the other must be held',
#  'father s voice the other must be held the',
#  's voice the other must be held the worthier',
#  'voice the other must be held the worthier i',
#  'the other must be held the worthier i would',
#  'other must be held the worthier i would my',
#  'must be held the worthier i would my father',
#  'be held the worthier i would my father look',
#  'held the worthier i would my father look d',
#  'the worthier i would my father look d but',
#  'worthier i would my father look d but with',
#  'i would my father look d but with my',
#  'would my father look d but with my eyes',
#  'my father look d but with my eyes rather',
#  'father look d but with my eyes rather your',
#  'look d but with my eyes rather your eyes',
#  'd but with my eyes rather your eyes must',
#  'but with my eyes rather your eyes must with',
#  'with my eyes rather your eyes must with his',
#  'my eyes rather your eyes must with his judgment',
#  'eyes rather your eyes must with his judgment look',
#  'rather your eyes must with his judgment look i',
#  'your eyes must with his judgment look i do',
#  'eyes must with his judgment look i do entreat',
#  'must with his judgment look i do entreat your',
#  'with his judgment look i do entreat your grace',
#  'his judgment look i do entreat your grace to',
#  'judgment look i do entreat your grace to pardon',
#  'look i do entreat your grace to pardon me',
#  'i do entreat your grace to pardon me i',
#  'do entreat your grace to pardon me i know',
#  'entreat your grace to pardon me i know not',
#  'your grace to pardon me i know not by',
#  'grace to pardon me i know not by what',
#  'to pardon me i know not by what power',
#  'pardon me i know not by what power i',
#  'me i know not by what power i am',
#  'i know not by what power i am made',
#  'know not by what power i am made bold',
#  'not by what power i am made bold nor',
#  'by what power i am made bold nor how',
#  'what power i am made bold nor how it',
#  'power i am made bold nor how it may',
#  'i am made bold nor how it may concern',
#  'am made bold nor how it may concern my',
#  'made bold nor how it may concern my modesty',
#  'bold nor how it may concern my modesty in',
#  'nor how it may concern my modesty in such',
#  'how it may concern my modesty in such a',
#  'it may concern my modesty in such a presence',
#  'may concern my modesty in such a presence here',
#  'concern my modesty in such a presence here to',
#  'my modesty in such a presence here to plead',
#  'modesty in such a presence here to plead my',
#  'in such a presence here to plead my thoughts',
#  'such a presence here to plead my thoughts but',
#  'a presence here to plead my thoughts but i',
#  'presence here to plead my thoughts but i beseech',
#  'here to plead my thoughts but i beseech your',
#  'to plead my thoughts but i beseech your grace',
#  'plead my thoughts but i beseech your grace that',
#  'my thoughts but i beseech your grace that i',
#  'thoughts but i beseech your grace that i may',
#  'but i beseech your grace that i may know',
#  'i beseech your grace that i may know the',
#  'beseech your grace that i may know the worst',
#  'your grace that i may know the worst that',
#  'grace that i may know the worst that may',
#  'that i may know the worst that may befall',
#  'i may know the worst that may befall me',
#  'may know the worst that may befall me in',
#  'know the worst that may befall me in this',
#  'the worst that may befall me in this case',
#  'worst that may befall me in this case if',
#  'that may befall me in this case if i',
#  'may befall me in this case if i refuse',
#  'befall me in this case if i refuse to',
#  'me in this case if i refuse to wed',
#  'in this case if i refuse to wed demetrius',
#  'this case if i refuse to wed demetrius either',
#  'case if i refuse to wed demetrius either to',
#  'if i refuse to wed demetrius either to die',
#  'i refuse to wed demetrius either to die the',
#  'refuse to wed demetrius either to die the death',
#  'to wed demetrius either to die the death or',
#  'wed demetrius either to die the death or to',
#  'demetrius either to die the death or to abjure',
#  'either to die the death or to abjure for',
#  'to die the death or to abjure for ever',
#  'die the death or to abjure for ever the',
#  'the death or to abjure for ever the society',
#  'death or to abjure for ever the society of',
#  'or to abjure for ever the society of men',
#  'to abjure for ever the society of men therefore',
#  'abjure for ever the society of men therefore fair',
#  'for ever the society of men therefore fair hermia',
#  'ever the society of men therefore fair hermia question',
#  'the society of men therefore fair hermia question your',
#  'society of men therefore fair hermia question your desires',
#  'of men therefore fair hermia question your desires know',
#  'men therefore fair hermia question your desires know of',
#  'therefore fair hermia question your desires know of your',
#  'fair hermia question your desires know of your youth',
#  'hermia question your desires know of your youth examine',
#  'question your desires know of your youth examine well',
#  'your desires know of your youth examine well your',
#  'desires know of your youth examine well your blood',
#  'know of your youth examine well your blood whe',
#  'of your youth examine well your blood whe r',
#  'your youth examine well your blood whe r if',
#  'youth examine well your blood whe r if you',
#  'examine well your blood whe r if you yield',
#  'well your blood whe r if you yield not',
#  'your blood whe r if you yield not to',
#  'blood whe r if you yield not to your',
#  'whe r if you yield not to your father',
#  'r if you yield not to your father s',
#  'if you yield not to your father s choice',
#  'you yield not to your father s choice you',
#  'yield not to your father s choice you can',
#  'not to your father s choice you can endure',
#  'to your father s choice you can endure the',
#  'your father s choice you can endure the livery',
#  'father s choice you can endure the livery of',
#  's choice you can endure the livery of a',
#  'choice you can endure the livery of a nun',
#  'you can endure the livery of a nun for',
#  'can endure the livery of a nun for aye',
#  'endure the livery of a nun for aye to',
#  'the livery of a nun for aye to be',
#  'livery of a nun for aye to be in',
#  'of a nun for aye to be in shady',
#  'a nun for aye to be in shady cloister',
#  'nun for aye to be in shady cloister mew',
#  'for aye to be in shady cloister mew d',
#  'aye to be in shady cloister mew d to',
#  'to be in shady cloister mew d to live',
#  'be in shady cloister mew d to live a',
#  'in shady cloister mew d to live a barren',
#  'shady cloister mew d to live a barren sister',
#  'cloister mew d to live a barren sister all',
#  'mew d to live a barren sister all your',
#  'd to live a barren sister all your life',
#  'to live a barren sister all your life chanting',
#  'live a barren sister all your life chanting faint',
#  'a barren sister all your life chanting faint hymns',
#  'barren sister all your life chanting faint hymns to',
#  'sister all your life chanting faint hymns to the',
#  'all your life chanting faint hymns to the cold',
#  'your life chanting faint hymns to the cold fruitless',
#  'life chanting faint hymns to the cold fruitless moon',
#  'chanting faint hymns to the cold fruitless moon thrice',
#  'faint hymns to the cold fruitless moon thrice blessed',
#  'hymns to the cold fruitless moon thrice blessed they',
#  'to the cold fruitless moon thrice blessed they that',
#  'the cold fruitless moon thrice blessed they that master',
#  'cold fruitless moon thrice blessed they that master so',
#  'fruitless moon thrice blessed they that master so their',
#  'moon thrice blessed they that master so their blood',
#  'thrice blessed they that master so their blood to',
#  'blessed they that master so their blood to undergo',
#  'they that master so their blood to undergo such',
#  'that master so their blood to undergo such maiden',
#  'master so their blood to undergo such maiden pilgrimage',
#  'so their blood to undergo such maiden pilgrimage but',
#  'their blood to undergo such maiden pilgrimage but earthlier',
#  'blood to undergo such maiden pilgrimage but earthlier happy',
#  'to undergo such maiden pilgrimage but earthlier happy is',
#  'undergo such maiden pilgrimage but earthlier happy is the',
#  'such maiden pilgrimage but earthlier happy is the rose',
#  'maiden pilgrimage but earthlier happy is the rose distill',
#  'pilgrimage but earthlier happy is the rose distill d',
#  'but earthlier happy is the rose distill d than',
#  'earthlier happy is the rose distill d than that',
#  'happy is the rose distill d than that which',
#  'is the rose distill d than that which withering',
#  'the rose distill d than that which withering on',
#  'rose distill d than that which withering on the',
#  'distill d than that which withering on the virgin',
#  'd than that which withering on the virgin thorn',
#  'than that which withering on the virgin thorn grows',
#  'that which withering on the virgin thorn grows lives',
#  'which withering on the virgin thorn grows lives and',
#  'withering on the virgin thorn grows lives and dies',
#  'on the virgin thorn grows lives and dies in',
#  'the virgin thorn grows lives and dies in single',
#  'virgin thorn grows lives and dies in single blessedness',
#  'thorn grows lives and dies in single blessedness so',
#  'grows lives and dies in single blessedness so will',
#  'lives and dies in single blessedness so will i',
#  'and dies in single blessedness so will i grow',
#  'dies in single blessedness so will i grow so',
#  'in single blessedness so will i grow so live',
#  'single blessedness so will i grow so live so',
#  'blessedness so will i grow so live so die',
#  'so will i grow so live so die my',
#  'will i grow so live so die my lord',
#  'i grow so live so die my lord ere',
#  'grow so live so die my lord ere i',
#  'so live so die my lord ere i will',
#  'live so die my lord ere i will yield',
#  'so die my lord ere i will yield my',
#  'die my lord ere i will yield my virgin',
#  'my lord ere i will yield my virgin patent',
#  'lord ere i will yield my virgin patent up',
#  'ere i will yield my virgin patent up unto',
#  'i will yield my virgin patent up unto his',
#  'will yield my virgin patent up unto his lordship',
#  'yield my virgin patent up unto his lordship whose',
#  'my virgin patent up unto his lordship whose unwished',
#  'virgin patent up unto his lordship whose unwished yoke',
#  'patent up unto his lordship whose unwished yoke my',
#  'up unto his lordship whose unwished yoke my soul',
#  'unto his lordship whose unwished yoke my soul consents',
#  'his lordship whose unwished yoke my soul consents not',
#  'lordship whose unwished yoke my soul consents not to',
#  'whose unwished yoke my soul consents not to give',
#  'unwished yoke my soul consents not to give sovereignty',
#  'yoke my soul consents not to give sovereignty take',
#  'my soul consents not to give sovereignty take time',
#  'soul consents not to give sovereignty take time to',
#  'consents not to give sovereignty take time to pause',
#  'not to give sovereignty take time to pause and',
#  'to give sovereignty take time to pause and by',
#  'give sovereignty take time to pause and by the',
#  'sovereignty take time to pause and by the next',
#  'take time to pause and by the next new',
#  'time to pause and by the next new moon',
#  'to pause and by the next new moon the',
#  'pause and by the next new moon the sealing',
#  'and by the next new moon the sealing day',
#  'by the next new moon the sealing day betwixt',
#  'the next new moon the sealing day betwixt my',
#  'next new moon the sealing day betwixt my love',
#  'new moon the sealing day betwixt my love and',
#  'moon the sealing day betwixt my love and me',
#  'the sealing day betwixt my love and me for',
#  'sealing day betwixt my love and me for everlasting',
#  'day betwixt my love and me for everlasting bond',
#  'betwixt my love and me for everlasting bond of',
#  'my love and me for everlasting bond of fellowship',
#  'love and me for everlasting bond of fellowship upon',
#  'and me for everlasting bond of fellowship upon that',
#  'me for everlasting bond of fellowship upon that day',
#  'for everlasting bond of fellowship upon that day either',
#  'everlasting bond of fellowship upon that day either prepare',
#  'bond of fellowship upon that day either prepare to',
#  'of fellowship upon that day either prepare to die',
#  'fellowship upon that day either prepare to die for',
#  'upon that day either prepare to die for disobedience',
#  'that day either prepare to die for disobedience to',
#  'day either prepare to die for disobedience to your',
#  'either prepare to die for disobedience to your father',
#  'prepare to die for disobedience to your father s',
#  'to die for disobedience to your father s will',
#  'die for disobedience to your father s will or',
#  'for disobedience to your father s will or else',
#  'disobedience to your father s will or else to',
#  'to your father s will or else to wed',
#  'your father s will or else to wed demetrius',
#  'father s will or else to wed demetrius as',
#  's will or else to wed demetrius as he',
#  'will or else to wed demetrius as he would',
#  'or else to wed demetrius as he would or',
#  'else to wed demetrius as he would or on',
#  'to wed demetrius as he would or on diana',
#  'wed demetrius as he would or on diana s',
#  'demetrius as he would or on diana s altar',
#  'as he would or on diana s altar to',
#  'he would or on diana s altar to protest',
#  'would or on diana s altar to protest for',
#  'or on diana s altar to protest for aye',
#  'on diana s altar to protest for aye austerity',
#  'diana s altar to protest for aye austerity and',
#  's altar to protest for aye austerity and single',
#  'altar to protest for aye austerity and single life',
#  'to protest for aye austerity and single life relent',
#  'protest for aye austerity and single life relent sweet',
#  'for aye austerity and single life relent sweet hermia',
#  'aye austerity and single life relent sweet hermia and',
#  'austerity and single life relent sweet hermia and lysander',
#  'and single life relent sweet hermia and lysander yield',
#  'single life relent sweet hermia and lysander yield thy',
#  'life relent sweet hermia and lysander yield thy crazed',
#  'relent sweet hermia and lysander yield thy crazed title',
#  'sweet hermia and lysander yield thy crazed title to',
#  'hermia and lysander yield thy crazed title to my',
#  'and lysander yield thy crazed title to my certain',
#  'lysander yield thy crazed title to my certain right',
#  'yield thy crazed title to my certain right you',
#  'thy crazed title to my certain right you have',
#  'crazed title to my certain right you have her',
#  'title to my certain right you have her father',
#  'to my certain right you have her father s',
#  'my certain right you have her father s love',
#  'certain right you have her father s love demetrius',
#  'right you have her father s love demetrius let',
#  'you have her father s love demetrius let me',
#  'have her father s love demetrius let me have',
#  'her father s love demetrius let me have hermia',
#  'father s love demetrius let me have hermia s',
#  's love demetrius let me have hermia s do',
#  'love demetrius let me have hermia s do you',
#  'demetrius let me have hermia s do you marry',
#  'let me have hermia s do you marry him',
#  'me have hermia s do you marry him scornful',
#  'have hermia s do you marry him scornful lysander',
#  'hermia s do you marry him scornful lysander true',
#  's do you marry him scornful lysander true he',
#  'do you marry him scornful lysander true he hath',
#  'you marry him scornful lysander true he hath my',
#  'marry him scornful lysander true he hath my love',
#  'him scornful lysander true he hath my love and',
#  'scornful lysander true he hath my love and what',
#  'lysander true he hath my love and what is',
#  'true he hath my love and what is mine',
#  'he hath my love and what is mine my',
#  'hath my love and what is mine my love',
#  'my love and what is mine my love shall',
#  'love and what is mine my love shall render',
#  'and what is mine my love shall render him',
#  'what is mine my love shall render him and',
#  'is mine my love shall render him and she',
#  'mine my love shall render him and she is',
#  'my love shall render him and she is mine',
#  'love shall render him and she is mine and',
#  'shall render him and she is mine and all',
#  'render him and she is mine and all my',
#  'him and she is mine and all my right',
#  'and she is mine and all my right of',
#  'she is mine and all my right of her',
#  'is mine and all my right of her i',
#  'mine and all my right of her i do',
#  'and all my right of her i do estate',
#  'all my right of her i do estate unto',
#  'my right of her i do estate unto demetrius',
#  'right of her i do estate unto demetrius i',
#  'of her i do estate unto demetrius i am',
#  'her i do estate unto demetrius i am my',
#  'i do estate unto demetrius i am my lord',
#  'do estate unto demetrius i am my lord as',
#  'estate unto demetrius i am my lord as well',
#  'unto demetrius i am my lord as well deriv',
#  'demetrius i am my lord as well deriv d',
#  'i am my lord as well deriv d as',
#  'am my lord as well deriv d as he',
#  'my lord as well deriv d as he as',
#  'lord as well deriv d as he as well',
#  'as well deriv d as he as well possess',
#  'well deriv d as he as well possess d',
#  'deriv d as he as well possess d my',
#  'd as he as well possess d my love',
#  'as he as well possess d my love is',
#  'he as well possess d my love is more',
#  'as well possess d my love is more than',
#  'well possess d my love is more than his',
#  'possess d my love is more than his my',
#  'd my love is more than his my fortunes',
#  'my love is more than his my fortunes every',
#  'love is more than his my fortunes every way',
#  'is more than his my fortunes every way as',
#  'more than his my fortunes every way as fairly',
#  'than his my fortunes every way as fairly rank',
#  'his my fortunes every way as fairly rank d',
#  'my fortunes every way as fairly rank d if',
#  'fortunes every way as fairly rank d if not',
#  'every way as fairly rank d if not with',
#  'way as fairly rank d if not with vantage',
#  'as fairly rank d if not with vantage as',
#  'fairly rank d if not with vantage as demetrius',
#  'rank d if not with vantage as demetrius and',
#  'd if not with vantage as demetrius and which',
#  'if not with vantage as demetrius and which is',
#  'not with vantage as demetrius and which is more',
#  'with vantage as demetrius and which is more than',
#  'vantage as demetrius and which is more than all',
#  'as demetrius and which is more than all these',
#  'demetrius and which is more than all these boasts',
#  'and which is more than all these boasts can',
#  'which is more than all these boasts can be',
#  'is more than all these boasts can be i',
#  'more than all these boasts can be i am',
#  'than all these boasts can be i am belov',
#  'all these boasts can be i am belov d',
#  'these boasts can be i am belov d of',
#  'boasts can be i am belov d of beauteous',
#  'can be i am belov d of beauteous hermia',
#  'be i am belov d of beauteous hermia why',
#  'i am belov d of beauteous hermia why should',
#  'am belov d of beauteous hermia why should not',
#  'belov d of beauteous hermia why should not i',
#  'd of beauteous hermia why should not i then',
#  'of beauteous hermia why should not i then prosecute',
#  'beauteous hermia why should not i then prosecute my',
#  'hermia why should not i then prosecute my right',
#  'why should not i then prosecute my right demetrius',
#  'should not i then prosecute my right demetrius i',
#  'not i then prosecute my right demetrius i ll',
#  'i then prosecute my right demetrius i ll avouch',
#  'then prosecute my right demetrius i ll avouch it',
#  'prosecute my right demetrius i ll avouch it to',
#  'my right demetrius i ll avouch it to his',
#  'right demetrius i ll avouch it to his head',
#  'demetrius i ll avouch it to his head made',
#  'i ll avouch it to his head made love',
#  'll avouch it to his head made love to',
#  'avouch it to his head made love to nedar',
#  'it to his head made love to nedar s',
#  'to his head made love to nedar s daughter',
#  'his head made love to nedar s daughter helena',
#  'head made love to nedar s daughter helena and',
#  'made love to nedar s daughter helena and won',
#  'love to nedar s daughter helena and won her',
#  'to nedar s daughter helena and won her soul',
#  'nedar s daughter helena and won her soul and',
#  's daughter helena and won her soul and she',
#  'daughter helena and won her soul and she sweet',
#  'helena and won her soul and she sweet lady',
#  'and won her soul and she sweet lady dotes',
#  'won her soul and she sweet lady dotes devoutly',
#  'her soul and she sweet lady dotes devoutly dotes',
#  'soul and she sweet lady dotes devoutly dotes dotes',
#  'and she sweet lady dotes devoutly dotes dotes in',
#  'she sweet lady dotes devoutly dotes dotes in idolatry',
#  'sweet lady dotes devoutly dotes dotes in idolatry upon',
#  'lady dotes devoutly dotes dotes in idolatry upon this',
#  'dotes devoutly dotes dotes in idolatry upon this spotted',
#  'devoutly dotes dotes in idolatry upon this spotted and',
#  'dotes dotes in idolatry upon this spotted and inconstant',
#  'dotes in idolatry upon this spotted and inconstant man',
#  'in idolatry upon this spotted and inconstant man i',
#  'idolatry upon this spotted and inconstant man i must',
#  'upon this spotted and inconstant man i must confess',
#  'this spotted and inconstant man i must confess that',
#  'spotted and inconstant man i must confess that i',
#  'and inconstant man i must confess that i have',
#  'inconstant man i must confess that i have heard',
#  'man i must confess that i have heard so',
#  'i must confess that i have heard so much',
#  'must confess that i have heard so much and',
#  'confess that i have heard so much and with',
#  'that i have heard so much and with demetrius',
#  'i have heard so much and with demetrius thought',
#  'have heard so much and with demetrius thought to',
#  'heard so much and with demetrius thought to have',
#  'so much and with demetrius thought to have spoke',
#  'much and with demetrius thought to have spoke thereof',
#  'and with demetrius thought to have spoke thereof but',
#  'with demetrius thought to have spoke thereof but being',
#  'demetrius thought to have spoke thereof but being over',
#  'thought to have spoke thereof but being over full',
#  'to have spoke thereof but being over full of',
#  'have spoke thereof but being over full of self',
#  'spoke thereof but being over full of self affairs',
#  'thereof but being over full of self affairs my',
#  'but being over full of self affairs my mind',
#  'being over full of self affairs my mind did',
#  'over full of self affairs my mind did lose',
#  'full of self affairs my mind did lose it',
#  'of self affairs my mind did lose it but',
#  'self affairs my mind did lose it but demetrius',
#  'affairs my mind did lose it but demetrius come',
#  'my mind did lose it but demetrius come and',
#  'mind did lose it but demetrius come and come',
#  'did lose it but demetrius come and come egeus',
#  'lose it but demetrius come and come egeus you',
#  'it but demetrius come and come egeus you shall',
#  'but demetrius come and come egeus you shall go',
#  'demetrius come and come egeus you shall go with',
#  'come and come egeus you shall go with me',
#  'and come egeus you shall go with me i',
#  'come egeus you shall go with me i have',
#  'egeus you shall go with me i have some',
#  'you shall go with me i have some private',
#  'shall go with me i have some private schooling',
#  'go with me i have some private schooling for',
#  'with me i have some private schooling for you',
#  'me i have some private schooling for you both',
#  'i have some private schooling for you both for',
#  'have some private schooling for you both for you',
#  'some private schooling for you both for you fair',
#  'private schooling for you both for you fair hermia',
#  'schooling for you both for you fair hermia look',
#  'for you both for you fair hermia look you',
#  'you both for you fair hermia look you arm',
#  'both for you fair hermia look you arm yourself',
#  'for you fair hermia look you arm yourself to',
#  'you fair hermia look you arm yourself to fit',
#  'fair hermia look you arm yourself to fit your',
#  'hermia look you arm yourself to fit your fancies',
#  'look you arm yourself to fit your fancies to',
#  'you arm yourself to fit your fancies to your',
#  'arm yourself to fit your fancies to your father',
#  'yourself to fit your fancies to your father s',
#  'to fit your fancies to your father s will',
#  'fit your fancies to your father s will or',
#  'your fancies to your father s will or else',
#  'fancies to your father s will or else the',
#  'to your father s will or else the law',
#  'your father s will or else the law of',
#  'father s will or else the law of athens',
#  's will or else the law of athens yields',
#  'will or else the law of athens yields you',
#  'or else the law of athens yields you up',
#  'else the law of athens yields you up which',
#  'the law of athens yields you up which by',
#  'law of athens yields you up which by no',
#  'of athens yields you up which by no means',
#  'athens yields you up which by no means we',
#  'yields you up which by no means we may',
#  'you up which by no means we may extenuate',
#  'up which by no means we may extenuate to',
#  'which by no means we may extenuate to death',
#  'by no means we may extenuate to death or',
#  'no means we may extenuate to death or to',
#  'means we may extenuate to death or to a',
#  'we may extenuate to death or to a vow',
#  'may extenuate to death or to a vow of',
#  'extenuate to death or to a vow of single',
#  'to death or to a vow of single life',
#  'death or to a vow of single life come',
#  'or to a vow of single life come my',
#  'to a vow of single life come my hippolyta',
#  'a vow of single life come my hippolyta what',
#  'vow of single life come my hippolyta what cheer',
#  'of single life come my hippolyta what cheer my',
#  'single life come my hippolyta what cheer my love',
#  'life come my hippolyta what cheer my love demetrius',
#  'come my hippolyta what cheer my love demetrius and',
#  'my hippolyta what cheer my love demetrius and egeus',
#  'hippolyta what cheer my love demetrius and egeus go',
#  'what cheer my love demetrius and egeus go along',
#  'cheer my love demetrius and egeus go along i',
#  'my love demetrius and egeus go along i must',
#  'love demetrius and egeus go along i must employ',
#  'demetrius and egeus go along i must employ you',
#  'and egeus go along i must employ you in',
#  'egeus go along i must employ you in some',
#  'go along i must employ you in some business',
#  'along i must employ you in some business against',
#  'i must employ you in some business against our',
#  'must employ you in some business against our nuptial',
#  'employ you in some business against our nuptial and',
#  'you in some business against our nuptial and confer',
#  'in some business against our nuptial and confer with',
#  'some business against our nuptial and confer with you',
#  'business against our nuptial and confer with you of',
#  'against our nuptial and confer with you of something',
#  'our nuptial and confer with you of something nearly',
#  'nuptial and confer with you of something nearly that',
#  'and confer with you of something nearly that concerns',
#  'confer with you of something nearly that concerns yourselves',
#  'with you of something nearly that concerns yourselves with',
#  'you of something nearly that concerns yourselves with duty',
#  'of something nearly that concerns yourselves with duty and',
#  'something nearly that concerns yourselves with duty and desire',
#  'nearly that concerns yourselves with duty and desire we',
#  'that concerns yourselves with duty and desire we follow',
#  'concerns yourselves with duty and desire we follow you',
#  'yourselves with duty and desire we follow you how',
#  'with duty and desire we follow you how now',
#  'duty and desire we follow you how now my',
#  'and desire we follow you how now my love',
#  'desire we follow you how now my love why',
#  'we follow you how now my love why is',
#  'follow you how now my love why is your',
#  'you how now my love why is your cheek',
#  'how now my love why is your cheek so',
#  'now my love why is your cheek so pale',
#  'my love why is your cheek so pale how',
#  'love why is your cheek so pale how chance',
#  'why is your cheek so pale how chance the',
#  'is your cheek so pale how chance the roses',
#  'your cheek so pale how chance the roses there',
#  'cheek so pale how chance the roses there do',
#  'so pale how chance the roses there do fade',
#  'pale how chance the roses there do fade so',
#  'how chance the roses there do fade so fast',
#  'chance the roses there do fade so fast belike',
#  'the roses there do fade so fast belike for',
#  'roses there do fade so fast belike for want',
#  'there do fade so fast belike for want of',
#  'do fade so fast belike for want of rain',
#  'fade so fast belike for want of rain which',
#  'so fast belike for want of rain which i',
#  'fast belike for want of rain which i could',
#  'belike for want of rain which i could well',
#  'for want of rain which i could well beteem',
#  'want of rain which i could well beteem them',
#  'of rain which i could well beteem them from',
#  'rain which i could well beteem them from the',
#  'which i could well beteem them from the tempest',
#  'i could well beteem them from the tempest of',
#  'could well beteem them from the tempest of mine',
#  'well beteem them from the tempest of mine eyes',
#  'beteem them from the tempest of mine eyes ay',
#  ...]

# %%
len(raw_seq)
# Out:
# 60898

# %%
seq_new = []

for i in clean_data:
  for j in i:
    seq_new.append(j)

# %%
len(seq_new)
# Out:
# 302259

# %%
#creat input & target sequence
x = []
y = []

for i in raw_seq:
  x.append(" ".join(i.split()[:-1]))
  y.append(" ".join(i.split()[1:]))

# %%
len(x) , len(y)
# Out:
# (60898, 60898)

# %%
# create int-to-word

int2word = {}
c = 0
uni_word = set((clean_data).split())

for index,word in enumerate(uni_word):
  int2word[index] = word

int_2_word = {index:word for index,word in enumerate(uni_word)}
word2int = {word:index for index,word in int2word.items()}

# %%
len(int_2_word)
# Out:
# 6187

# %%
len(int2word)
# Out:
# 6187

# %%
len(word2int)
# Out:
# 6187

# %%
vocab_size = len(int2word)
vocab_size
# Out:
# 6187

# %%
def get_int_seq(seq):
  return [word2int[w] for w in seq.split()]

# %%
#x and y covert in into int
x_int = [get_int_seq(i) for i in x]
y_int = [get_int_seq(j) for j in y]

# %%
#convert lists to numpy arrays
x_int = np.array(x_int)
y_int = np.array(y_int)

# %%
x_int
# Out:
# array([[4699, 6048, 5395, ..., 4736, 1264, 1454],
#        [6048, 5395, 2886, ..., 1264, 1454, 3816],
#        [5395, 2886, 5208, ..., 1454, 3816,  458],
#        ...,
#        [5389, 4697, 3611, ..., 3830, 2578, 1929],
#        [4697, 3611, 3912, ..., 2578, 1929, 1556],
#        [3611, 3912, 4678, ..., 1929, 1556, 6048]])

# %%
len(x_int) , len(y_int)
# Out:
# (60898, 60898)

# %%
x_int.dtype
# Out:
# dtype('int64')

# %%
inputs = x_int
targets = y_int

# %%
#train , test & validation
train_ratio = 0.8
valid_ratio = (1-train_ratio)/2

total = len(x_int)
train_cutoff = int((total*train_ratio))
valid_cutoff = int((total*(1-valid_ratio)))


#numpy to tensor
train_x, train_y = torch.Tensor(inputs[:train_cutoff]).long() , torch.Tensor(targets[:train_cutoff]).long()
valid_x , valid_y = torch.Tensor(inputs[train_cutoff:valid_cutoff]).long() , torch.Tensor(targets[train_cutoff:valid_cutoff]).long()


train_data = TensorDataset(train_x,train_y)
valid_data = TensorDataset(valid_x ,valid_y)


batch_size = 32


train_loader = DataLoader(train_data,batch_size = batch_size,shuffle=True,drop_last=True)
valid_loader = DataLoader(valid_data,batch_size = batch_size,shuffle=True,drop_last=True)

# %%
for x , y in train_loader:
  print(x.shape,y.shape)
  break
# Out:
# torch.Size([32, 8]) torch.Size([32, 8])

# %%
x_int.shape
# Out:
# (60898, 8)

# %%
y_int.shape
# Out:
# (60898, 8)

# %%
class ShakespeareGenerationLSTM(nn.Module):

  def __init__(self,n_vocab,n_embed,n_hidden,n_layers,drop_pr = 0.25):
    super().__init__()
    self.n_vocab = n_vocab
    self.n_embed = n_embed
    self.n_hidden = n_hidden 
    self.drop_pr = drop_pr 
    self.n_layers = n_layers

    self.embedding = nn.Embedding(n_vocab,n_embed)
    self.lstm = nn.LSTM(n_embed,n_hidden,n_layers,batch_first = True)
    self.dropout = nn.Dropout(drop_pr)
    self.fc = nn.Linear(n_hidden,n_vocab)

  #(input , (hidden_state & cell state))
  def forward(self,x,hidden):
    
    #pass the input through embedding layers
    embedded = self.embedding(x)

    #Get the output and new hidden state and cell state
    n_out , hidden = self.lstm(embedded,hidden) #(lstm) (input,(hidden_state,cell_state)) 

    #pass the droupout
    out = self.dropout(n_out)

    #reshape
    #out = out.contingous().view(-1,self.n_hidden)
    out = out.reshape(-1,self.n_hidden)

    out = self.fc(out)

    return out,hidden


  def init_hidden(self,batch_size):
    weights = next(self.parameters()).data

    if (torch.cuda.is_available()):
      hidden = (weights.new(self.n_layers , batch_size,self.n_hidden).zero_().cuda(),
         weights.new(self.n_layers,batch_size,self.n_hidden).zero_().cuda())

    else:
      hidden = (weights.new(self.n_layers , batch_size,self.n_hidden).zero_(),
         weights.new(self.n_layers,batch_size,self.n_hidden).zero_())
      
    return hidden

# %%
#n_vocab,n_embed,n_hidden,n_layers,drop_pr = 0.25
n_vocab = len(int2word)
n_embed = 256
n_layers = 4
n_hidden = 128

model = ShakespeareGenerationLSTM(n_vocab,n_embed,n_hidden,n_layers,drop_pr = 0.25)

# %%
model
model.cuda()
# Out:
# ShakespeareGenerationLSTM(
#   (embedding): Embedding(6187, 256)
#   (lstm): LSTM(256, 128, num_layers=4, batch_first=True)
#   (dropout): Dropout(p=0.25, inplace=False)
#   (fc): Linear(in_features=128, out_features=6187, bias=True)
# )

# %%
print(model)
# Out:
# ShakespeareGenerationLSTM(
#   (embedding): Embedding(6187, 256)
#   (lstm): LSTM(256, 128, num_layers=4, batch_first=True)
#   (dropout): Dropout(p=0.25, inplace=False)
#   (fc): Linear(in_features=128, out_features=6187, bias=True)
# )

# %%
optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
loss_fn = nn.CrossEntropyLoss()

# %%
def train_sentiment(model,loss_fn,optimizer,epochs=20):

  for epoch in range(epochs):
    h = model.init_hidden(batch_size=32)
    train_loss = 0.0
    train_acc = 0.0
    valid_loss = 0.0
    valid_acc = 0.0


    model.train()

    for input,labels in train_loader:
      h = tuple([i.data for i in h]) #tuple([hidden_state,cell_state])
      input , labels = input.cuda() , labels.cuda()
      #print(input.shape,labels.shape)
     
    
      output,h = model(input,h)
      optimizer.zero_grad()

      loss = loss_fn(output,labels.view(-1))
      loss.backward()
      train_loss += loss.item()

      optimizer.step()

    model.eval()

    for input,labels in valid_loader:
      input , labels = input.cuda() , labels.cuda()
      h = tuple([i.data for i in h]) #tuple([hidden_state,cell_state])
      output,h = model(input,h)
      

      loss = loss_fn(output,labels.view(-1))
      valid_loss += loss.item()

    print("Epoch {} , Train_loss : {:.2f},valid_loss : {:.2f}".format(
        epoch+1 , train_loss/len(train_loader),valid_loss/len(valid_loader)))

# %%
train_sentiment(model,loss_fn,optimizer,epochs=30)
# Out:
# Epoch 1 , Train_loss : 6.29,valid_loss : 6.58
# Epoch 2 , Train_loss : 5.57,valid_loss : 6.81
# Epoch 3 , Train_loss : 5.10,valid_loss : 7.14
# Epoch 4 , Train_loss : 4.78,valid_loss : 7.38
# Epoch 5 , Train_loss : 4.53,valid_loss : 7.59
# Epoch 6 , Train_loss : 4.33,valid_loss : 7.82
# Epoch 7 , Train_loss : 4.16,valid_loss : 8.07
# Epoch 8 , Train_loss : 4.01,valid_loss : 8.28
# Epoch 9 , Train_loss : 3.88,valid_loss : 8.48
# Epoch 10 , Train_loss : 3.76,valid_loss : 8.68
# Epoch 11 , Train_loss : 3.66,valid_loss : 8.79
# Epoch 12 , Train_loss : 3.56,valid_loss : 9.00
# Epoch 13 , Train_loss : 3.47,valid_loss : 9.17
# Epoch 14 , Train_loss : 3.40,valid_loss : 9.31
# Epoch 15 , Train_loss : 3.32,valid_loss : 9.43
# Epoch 16 , Train_loss : 3.24,valid_loss : 9.55
# Epoch 17 , Train_loss : 3.18,valid_loss : 9.63
# Epoch 18 , Train_loss : 3.11,valid_loss : 9.73
# Epoch 19 , Train_loss : 3.05,valid_loss : 9.87
# Epoch 20 , Train_loss : 3.00,valid_loss : 9.94
# Epoch 21 , Train_loss : 2.95,valid_loss : 10.01
# Epoch 22 , Train_loss : 2.90,valid_loss : 10.08
# Epoch 23 , Train_loss : 2.84,valid_loss : 10.10
# Epoch 24 , Train_loss : 2.80,valid_loss : 10.20
# Epoch 25 , Train_loss : 2.76,valid_loss : 10.29
# Epoch 26 , Train_loss : 2.72,valid_loss : 10.30
# Epoch 27 , Train_loss : 2.68,valid_loss : 10.39
# Epoch 28 , Train_loss : 2.64,valid_loss : 10.45
# Epoch 29 , Train_loss : 2.60,valid_loss : 10.48
# Epoch 30 , Train_loss : 2.56,valid_loss : 10.58

# %%
def predict(model,tkn,h = None):
  x = np.array([[word2int[tkn]]])
  inputs = torch.from_numpy(x)
  inputs = inputs.cuda()
  h = tuple([i.data for i in h])

  # get the output of the model
  out , h = model(inputs,h)
  # get the token proba
  p = F.softmax(out,dim=1).data # cuda  

  p = p.cpu()
  p = p.numpy()

  p = p.reshape(p.shape[1],)

  #get indices of next or top 3 values
  top_n_indx = p.argsort()[-1:][::-1][0]

  #random selct one of the two indecies 

  return int2word[top_n_indx] , h

# %%
#function generate text
def generate_text(model,size,prime="she lingers my desires"):

  # To GPU
  model.cuda()

  model.eval()

  #batch size as 1
  h = model.init_hidden(1)

  tokens = prime.split() # ["it","is","good"]

  #predict next token
  for t in tokens:
    token , h = predict(model,t.lower(),h)

  tokens.append(token)

  #predict subsequent toekns

  for i in range(size):
    token , h  = predict(model,tokens[-1],h)
    tokens.append(token)

  return " ".join(tokens)

# %%
generate_text(model,100,"old moon wanes she lingers my desires")
# Out:
# 'old moon wanes she lingers my desires like to a second fool captain if i come to the camp he does me wrong my lord if we must not so near at a man s daughter i am not my lord the youngest son of sweet music what my life is in the world that hatred is so far from jealousy to sleep by love s sight of thy misprision must perforce found for by his life s noontide with the antipodes it cannot be but i thank your majesty i will not bate thee a scruple well i shall be dogged with company and our devices known'
